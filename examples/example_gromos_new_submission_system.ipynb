# %% [markdown]
# # Example Notebook for the Usage of the New Submission System

# %% [markdown]
# Note that you need support for the new `PyGromosTools` submission system shipped with `relase3`.

# %%
# necessary imports are the Gromos_System and convenience functions emin and md
from pygromos.files.gromos_system.gromos_system import Gromos_System
from pygromos.simulations.modules.preset_simulation_modules import emin, md
# Out:
# LICENSE: Could not open license file "oe_license.txt" in local directory
# LICENSE: N.B. OE_LICENSE environment variable is not set
# LICENSE: N.B. OE_DIR environment variable is not set
# LICENSE: No product keys!
# LICENSE: No product keys!
# LICENSE: No product keys!
# Warning: Unable to load toolkit 'OpenEye Toolkit'. The Open Force Field Toolkit does not require the OpenEye Toolkits, and can use RDKit/AmberTools instead. However, if you have a valid license for the OpenEye Toolkits, consider installing them for faster performance and additional file format support: https://docs.eyesopen.com/toolkits/python/quickstart-python/linuxosx.html OpenEye offers free Toolkit licenses for academics: https://www.eyesopen.com/academic-licensing
# LICENSE: No product keys!

# %% [markdown]
# ## Initialization
# Set up path to binaries and instantiate an initial `Gromos_System` object

# %%
# binaries
gromosPP = "/home/fpultar/bin/gromos++/bin"
gromosXX = "/home/fpultar/bin/gromosXX/bin"

# folders and title
system_name = "menthol-dmf-example"
work_folder = f"/home/fpultar/Documents/calc/pygromos/{system_name}"

# files
in_cnf_path = f"example_files/submission-system-files/{system_name}-all-atom_54a7.cnf"
in_top_path = f"example_files/submission-system-files/{system_name}-all-atom_54a7.top"

# system
system = Gromos_System(
    work_folder, 
    system_name, 
    in_top_path=in_top_path, 
    in_cnf_path=in_cnf_path,
    in_gromosPP_bin_dir=gromosPP,
    in_gromosXX_bin_dir=gromosXX,
    verbose=False
)

# %% [markdown]
# ## Energy minimization

# %% [markdown]
# Take advantage of the new submission system: convenience functions such as `emin` take in a parametrized `Gromos_System` object, automatically set up the calculation and return a new `Gromos_System` object with updated file paths.

# %%
# run energy minimization
minimized_system = emin(system)
# Out:
# ################################################################################
#
# emin
# ################################################################################
#
# ============================================================
# FOUND RESULT: /home/fpultar/Documents/calc/pygromos/menthol-dmf-example/emin/analysis/data/emin.cnf
#  GOING TO SKIPT THIS SUBMISSION!
# /home/fpultar/Documents/repos/PyGromosTools/pygromos/files/gromos_system/gromos_system.py:601: UserWarning: Did not change file path as its only promised None
#   if(self.verbose or True): warnings.warn("Did not change file path as its only promised " + str(file_obj.path))
# /home/fpultar/Documents/repos/PyGromosTools/pygromos/simulations/modules/general_simulation_modules.py:96: UserWarning: Template_imd_path was used: /home/fpultar/Documents/repos/PyGromosTools/pygromos/data/simulation_parameters_templates/emin.imd
#   if(verbose): warnings.warn("Template_imd_path was used: "+_template_imd_path)

# %% [markdown]
# ### Print out the new file paths

# %% [markdown]
# Note how the new `Gromos_System` object has new file paths associated with it.

# %%
print(minimized_system.imd.path)
print(minimized_system.top.path)
print(minimized_system.cnf.path)
# Out:
# /home/fpultar/Documents/calc/pygromos/menthol-dmf-example/emin/input/emin.imd
# /home/fpultar/Documents/calc/pygromos/menthol-dmf-example/emin/input/emin.top
# /home/fpultar/Documents/calc/pygromos/menthol-dmf-example/emin/analysis/data/emin.cnf

# %% [markdown]
# ### Visualize the minimized system

# %%
minimized_system.cnf.visualize()
# Out:
# <div id="3dmolviewer_1644589492992557"  style="position: relative; width: 400px; height: 400px">
#         <p id="3dmolwarning_1644589492992557" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1644589492992557 = null;
# var warn = document.getElementById("3dmolwarning_1644589492992557");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_
381780    10.997522700    0.335471040\nH  \t 9.443831840    11.899188980    0.309687050\nC  \t 11.341027340    11.232308440    42.555592900\nC  \t 11.744854850    12.561376890    42.105679480\nC  \t 12.413098400    10.242537200    42.608505670\nC  \t 11.406786920    34.938749270    14.468083860\nC  \t 11.756972770    35.782736320    13.644627980\nH  \t 12.563272430    36.487927420    13.895129240\nC  \t 11.326225980    35.904442650    12.370993500\nC  \t 11.733975560    37.040303620    11.549185850\nC  \t 10.536771980    34.886603400    11.683620500\nC  \t 29.039153210    7.741828350    11.731512470\nC  \t 28.854511930    6.743825100    11.036485880\nH  \t 28.512996860    5.811128560    11.509185200\nC  \t 29.04788 ...

# %% [markdown]
# **Note:** The new `Gromos_System` object has an .imd file associated (from the energy minimization). Using the object for a subsequent calculation requires the .imd to be reset (as shown below) or a new `Imd` object to be passed to the function `md`. Otherwise `md` will be based on the previous (emin) input file.

# %%
# Reset the old imd from emin 
minimized_system.imd = None

# %% [markdown]
# ## Equilibration followed by subsequent production runs

# %%
md_system = md(minimized_system, equilibration_runs=1, simulation_runs=2)
# Out:
# /home/fpultar/Documents/repos/PyGromosTools/pygromos/simulations/modules/general_simulation_modules.py:96: UserWarning: Template_imd_path was used: /home/fpultar/Documents/repos/PyGromosTools/pygromos/data/simulation_parameters_templates/md.imd
#   if(verbose): warnings.warn("Template_imd_path was used: "+_template_imd_path)
# ################################################################################
#
# md
# ################################################################################
#
# ============================================================
# FOUND RESULT: /home/fpultar/Documents/calc/pygromos/menthol-dmf-example/md/analysis/data/md.cnf
#  GOING TO SKIPT THIS SUBMISSION!

# %% [markdown]
# Again, note how the new `Gromos_System` object has new file paths associated with it.

# %%
print(md_system.imd.path)
print(md_system.top.path)
print(md_system.cnf.path)
# Out:
# /home/fpultar/Documents/calc/pygromos/menthol-dmf-example/md/input/md.imd
# /home/fpultar/Documents/calc/pygromos/menthol-dmf-example/md/input/md.top
# /home/fpultar/Documents/calc/pygromos/menthol-dmf-example/md/analysis/data/md.cnf

# %% [markdown]
# ### Visualize the last configuration

# %%
md_system.cnf.visualize()
# Out:
# <div id="3dmolviewer_16445894988690035"  style="position: relative; width: 400px; height: 400px">
#         <p id="3dmolwarning_16445894988690035" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16445894988690035 = null;
# var warn = document.getElementById("3dmolwarning_16445894988690035");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16445894988690035 = $3Dmol.createViewer($("#3dmolviewer_16445894988690035"),{backgroundColor:"white"});
# viewer_16445894988690035.zoomTo();
# 	viewer_16445894988690035.addModel("3613\n# \tMD++\n# exported wit PyGromosTools\nC  \t 12.488661010    3.149404620    7.230576640\nC  \t 11.044932330    3.643296240    7.344762260\nC  \t 10.182912390    3.399711460    6.104330920\nC  \t 10.861800640    5.151958540    7.697548860\nC  \t 11.462633250    6.090616070    6.634644250\nC  \t 11.560669990    7.563009800    7.039083230\nC  \t 12.135779030    7.717146010    8.448603970\nC  \t 12.308055980    9.189124910    8.829330470\nC  \t 11.325501240    6.950410770    9.495817140\nC  \t 11.363704750    5.471062130    9.107262140\nH  \t 12.423856190    5.187775290    9.184956740\nO  \t 10.583514200    4.715531410    10.037687190\nH  \t 9.653268670    4.977524680    10.132424620\nC  \t 39.475955710    28.402295870    34.873551200\nC  \t 39